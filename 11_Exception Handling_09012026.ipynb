# %%
#Q1. Parse a deposit amount for banking case 1; use sample reference ACC-1001 and explain the result.
Account="ACC-1001"
Current_Balance=10000

try:
    Deposit_Amount=int(input())
    if Deposit_Amount<=0:
        raise ValueError("Deposit amount must be greater than zero")
except ValueError as e:
     print("Invalid deposit:",e) 
else:
     Current_Balance += Deposit_Amount
     print("Account:",Account)
     print("New_Balance:",Current_Balance)
# Out:
# Account: ACC-1001
# New_Balance: 10200

# %%
#Q2. Handle a missing account key for banking case 1; use sample reference ACC-1002 and explain the result.
Account={
    "ACC-1002":10000
}
try:
   Account_Number=input()
   if Account_Number not in Account:
            raise KeyError(f"The {Account_Number} is not found")
except KeyError as k:
     print("Invalid Account Number:",k)
  
else:
        print(Account)
# Out:
# {'ACC-1002': 10000}

# %%
#Q3. Prevent division by zero in average balance for banking case 1; use sample reference ACC-1003 and explain the result.
Account={
    "ACC-1001":10000,
    "ACC-1002":12500,
    "ACC-1003":15000
}


try:
    a=int(input())
    if a<=0:
        raise ZeroDivisionError("The Average Balance cannot divide by zero and Please enter Positive Value")
    # Average_Balance = Account["ACC-1003"] / a
except ZeroDivisionError as z:
    print("Invalid :",z)
else:
     Average_Balance=Account["ACC-1003"]/len(Account)
     print("Account:","ACC-1003")
     print(Average_Balance)
# Out:
# Account: ACC-1003
# 5000.0

# %%
#Q4.Open a transaction file safely for banking case 1; use sample reference ACC-1004 and explain the result.
Account={
    "Account_no":"ACC-1004",
    "Balance":10000
}    
try:
    file=open("transactions.txt","r")
except FileNotFoundError:
    print("File Not found")
else:
    print("Account:",Account["Account_no"])
    print("Transaction file opened suuccessfully ")
    file.close()  

# try:
#     Account_Number=str(input("Please Enter Account Number"))
#     if Account_Number !=Account["Account_no"]:
#         raise ValueError("Plese enter Valid Account Number")   
# except ValueError as k:
#     print("Invalid:",k)
# else:
#         if Account_Number == Account["Account_no"]:
#          Deposit=int(input())
#          Withdraw=int(input())
#         #  Account["Balance"]+ Deposit
#         #  Account["Balance"] -= Withdraw
#          New_balance=Account["Balance"]+Deposit-Withdraw
#          print("The Account Number:",Account_Number)
#          print("The Balance is:",Account["Balance"])   
#          print("The Deposit Amount is is:",Deposit)  
#          print("The Withdraw is:",Withdraw) 
#          print("The New Balance is:",New_balance)  
#         #  print(Account)
# Out:
# File Not found

# %%
#Q5.Reject a negative withdrawal for banking case 1; use sample reference ACC-1005 and explain the result.
Account={
    "Account_no":"ACC-1005",
    "Balance":10000,
}
try:
     Withdraw=int(input())
     if Withdraw <0:
            raise ValueError ("Withdraw cannot be negative")
     if Withdraw >= Account["Balance"] :
          raise ValueError("The Withdraw Amount is very High") 
except ValueError as e:
    print("Invalid:",e)
else:
    if Withdraw <= Account["Balance"] :
         Deposit=int(input())
         New_balance=Account["Balance"]+Deposit-Withdraw
         print("The Account Number:",Account["Account_no"])
         print("The Balance is:",Account["Balance"])   
         print("The Deposit Amount is is:",Deposit)  
         print("The Withdraw is:",Withdraw) 
         print("The New Balance is:",New_balance)
# Out:
# The Account Number: ACC-1005
# The Balance is: 10000
# The Deposit Amount is is: 400
# The Withdraw is: 300
# The New Balance is: 10100

# %%
#Q6.Catch invalid tenure input for banking case 1; use sample reference ACC-1006 and explain the result.
Account_no="ACC-1006"
Loan_Amount=10000
# Tenure=2

try:
    Tenure=int(input())
    if Tenure <= 0:
        raise ValueError("Tenure Cannot be negative and zero")
    if Tenure > 30:
        raise ValueError ("Tenure Cannot Exceed 30 years")
except ValueError as e:
    print("Tenure Invalid:",e) 
else:
    print("Account Number:",Account_no)       
    print("The loan Amount is:",Loan_Amount)
    print("The tenurity is:",Tenure)
# Out:
# Account Number: ACC-1006
# The loan Amount is: 10000
# The tenurity is: 3

# %%
#Q7. Use else after pin-format validation for banking case 1; use sample reference ACC-1007 and explain the result.
Account_no="ACC-1007"
original_pin=1234

try:
  pin=input("Enter 4 digit pin:")
  if len(pin)!=4 or not pin.isdigit():
        raise ValueError("PIN contains exactly 4 digits number")
  if int(pin) !=original_pin:
        raise ValueError("Please enter correct pin")
except ValueError as e:
    print("Pin Error:",e)
else:
    if int(pin)==original_pin: 
     print(Account_no)
     print("You have successfully loged in")
# Out:
# ACC-1007
# You have successfully loged in

# %%
#Q8.Use finally to close a session for banking case 1; use sample reference ACC-1008 and explain the result.
Account_no="ACC-1008"
Account_number=input()
try:
    if Account_no!=Account_number:
        raise ValueError("Please Enter Valid Account number")
except ValueError as e:
    print("Invalid:",e)
else:
    print("Successfully Entered Account Number")
finally:
    print("Thank you for banking with us")
# Out:
# Invalid: Please Enter Valid Account number
# Thank you for banking with us

# %%
#Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference ACC-1009 and explain the result.
Account_no="ACC-1009"
Balance=10000
Deposit=input()
try:
    # Deposit=int(input())
    # if not Deposit.isdigit():
    #     raise ValueError("The Deposit must contain numbers")
    if int(Deposit)<=0 :
        raise ValueError("The Deposit Amount should be greater than 0") 
except ValueError as e:
    print("Invalid:",e)
else:

    Balance += int(Deposit)
    print(Account_no)
    print(Deposit)   
    print(Balance)
# Out:
# ACC-1009
# 2000
# 12000

# %%
#Q10.Raise a clear valueerror for banking case 1; use sample reference ACC-1010 and explain the result.
Account_no="ACC-1010"
Account_number=input("Enter Account number")
try:
    if Account_number != Account_no:
        raise ValueError("The Account number should contain 3 capital alphabets with special character - including 4 digits")
except ValueError as e:
    print("Please Check:",e)
else:
    print(Account_number)
    print("You have entered Valid Account number")
# Out:
# ACC-1010
# You have entered Valid Account number

# %%
#Q11. Parse a deposit amount for banking case 2; use sample reference ACC-1011 and explain the result.
Account="ACC-1011"
Balance=1000
try:
    Deposit_Amount=int(input())
    if Deposit_Amount<=0:
        raise ValueError("Deposit amount must be greater than zero")
except ValueError as e:
     print("Invalid deposit:",e) 
else:
     Balance += Deposit_Amount
     print("Account:",Account)
     print("New_Balance:",Balance)
# Out:
# Invalid deposit: invalid literal for int() with base 10: 'abc'

# %%
#Q12.Handle a missing account key for banking case 2; use sample reference ACC-1012 and explain the result.
Account={
    "Account_no":"ACC-1012",
    "Balance":1000
}
Account_no=input()
try:
    if Account_no !=Account["Account_no"]:
        raise ValueError("Account number must be valid")
except ValueError as e:
    print("Invalid :",e)
else:
    print(Account)
# Out:
# Invalid : 'Account number must be valid'

# %%
#Q13.Prevent division by zero in average balance for banking case 2; use sample reference ACC-1013 and explain the result.
Account={
    "ACC-1011":10000,
    "ACC-1012":12500,
    "ACC-1013":15000
}


try:
    a=int(input())
    if a<=0:
        raise ZeroDivisionError("The Average Balance cannot divide by zero and Please enter Positive Value")
    # Average_Balance = Account["ACC-1013"] / a
except ZeroDivisionError as z:
    print("Invalid :",z)
else:
     Average_Balance=Account["ACC-1013"]/len(Account)
     print("Account:",list(Account)[2])
     print("Average Balance of ACC-1013:",Average_Balance)
# Out:
# Account: ACC-1013
# Average Balance of ACC-1013: 5000.0

# %%
#Q14.Open a transaction file safely for banking case 2; use sample reference ACC-1014 and explain the result.
Account={
    "Account_no":"ACC-1014",
    "Balance":1000
}
try:
    file=open("transaction","r")
except FileNotFoundError :
    print("File Not Found")
else:
    print("Account:",Account["Account_no"])
    print("Transaction File found")
# Out:
# File Not Found

# %%
#Q15. Reject a negative withdrawal for banking case 2; use sample reference ACC-1015 and explain the result.
Account_no="ACC-1015"
Balance=1000
try:
    Withdraw=float(input())
    if Withdraw <= 0:
        raise ValueError("Please Withdraw amount greater than zero")
    if Withdraw > Balance:
        raise ValueError("The Withdraw amount should be less than Balance")
except ValueError as e:
    print("Negative:",e)
else:
    Current_Balance=Balance-Withdraw
    print(Account_no)
    print(Balance)
    print(Current_Balance)
# Out:
# Negative: The Withdraw amount should be less than Balance

# %%
#Q16.Catch invalid tenure input for banking case 2; use sample reference ACC-1016 and explain the result.
Account_number="ACC-1016"
Loan_Amount=100000
Tenure=int(input())
try:
    if Tenure <=0 or Tenure>30:
        raise ValueError("Tenure must be between 1 and 30 years")
except ValueError as e:
    print("Tenure Error:",e)
else:
    print("Account Number:",Account_number)
    print("Loan Amount:",Loan_Amount)
    print("Loan Tenurity:",Tenure)
# Out:
# Account Number: ACC-1016
# Loan Amount: 100000
# Loan Tenurity: 30

# %%
#Q17. Use else after pin-format validation for banking case 2; use sample reference ACC-1017 and explain the result.
Account_number="ACC-1017"
try :
    pin=input()
    if len(pin) !=4 or not pin.isdigit():
      raise ValueError("The Pin must contain 4 digit Numbers only")
    # if int(pin) != original_pin:
    #    raise ValueError("The Pin is incorrect") 
except ValueError as e:
   print("Invalid Pin:",e)
else:
   print("Account Number:",Account_number)
   print("Pin Format is correct and Successfully logged in")
# Out:
# Invalid Pin: The Pin must contain 4 digit Numbers only

# %%
#Q18.Use finally to close a session for banking case 2; use sample reference ACC-1018 and explain the result.
Account_number="ACC-1018"
try:
    User_Account_Number=input()
    if User_Account_Number != Account_number:
        raise ValueError("Please enter correct account number")
except ValueError as e:
    print("Invalid Account Number:",e)
else:
    print("Account_number:",User_Account_Number)
finally:
    print("Thank You for banking with us")
# Out:
# Account_number: ACC-1018
# Thank You for banking with us

# %%
#Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference ACC-1019 and explain the result.
Account_number="ACC-1019"
Balance=10000

try:
#     Withdraw=input()
#     if Withdraw.strip() == "":
#             raise ValueError("Withdraw cannot be empty")
#     if not Withdraw.isdigit():
#             raise ValueError("The Withdraw Amount must have digits")
    Withdraw=int(input())
    if Withdraw<=0:
            raise ValueError("Withdraw must be greater than zero")
    if Withdraw >= Balance:
        raise ValueError("Withdraw amount must be less than Available Balance")
except ValueError as v:
    print("Invalid Withdraw:",v)
else:
    New_balance = Balance-Withdraw 
    print("Account Number:",Account_number)
    print("Balance:",Balance)
    print("Withdraw Amount is:",Withdraw)
    print("New Balance is:",New_balance)
# Out:
# Invalid Withdraw: Withdraw must be greater than zero

# %%
#Q20. Raise a clear valueerror for banking case 2; use sample reference ACC-1020 and explain the result.
Account_no="ACC-1010"
Account_number=input("Enter Account number")
try:
    if Account_number != Account_no:
        raise ValueError("The Account number should contain 3 capital alphabets with special character - including 4 digits")
except ValueError as e:
    print("Please Check:",e)
else:
    print(Account_number)
    print("You have entered Valid Account number")
# Out:
# Please Check: The Account number should contain 3 capital alphabets with special character - including 4 digits

# %%
#Q21.Parse a deposit amount for banking case 3; use sample reference ACC-1021 and explain the result.
Account="ACC-1021"
Balance=1000
try:
    Deposit_Amount=int(input())
    if Deposit_Amount<=0:
        raise ValueError("Deposit amount must be greater than zero")
except ValueError as e:
     print("Invalid deposit:",e) 
else:
     Balance += Deposit_Amount
     print("Account:",Account)
     print("New_Balance:",Balance)

# %%
#Q22. Handle a missing account key for banking case 3; use sample reference ACC-1022 and explain the result.
Account={
    "Account_no":"ACC-1022",
    "Balance":1000
}
Account_no=input()
try:
    if Account_no !=Account["Account_no"]:
        raise ValueError("Account number must be valid")
except ValueError as e:
    print("Invalid :",e)
else:
    print(Account)

# %%
#Q23. Prevent division by zero in average balance for banking case 3; use sample reference ACC-1023 and explain the result.
Account={
    "ACC-1021":10000,
    "ACC-1022":12500,
    "ACC-1023":15000
}


try:
    a=int(input())
    if a<=0:
        raise ZeroDivisionError("The Average Balance cannot divide by zero and Please enter Positive Value")
    # Average_Balance = Account["ACC-1013"] / a
except ZeroDivisionError as z:
    print("Invalid :",z)
else:
     Average_Balance=Account["ACC-1023"]/len(Account)
     print("Account:",list(Account)[2])
     print("Average Balance of ACC-1023:",Average_Balance)
# Out:
# Account: ACC-1023
# Average Balance of ACC-1023: 5000.0

# %%
#Q24. Open a transaction file safely for banking case 3; use sample reference ACC-1024 and explain the result.
Account={
    "Account_no":"ACC-1024",
    "Balance":1000
}
try:
    file=open("transaction","r")
except FileNotFoundError :
    print("File Not Found")
else:
    print("Account:",Account["Account_no"])
    print("Transaction File found")

# %%
#Q25. Reject a negative withdrawal for banking case 3; use sample reference ACC-1025 and explain the result.
Account_no="ACC-1025"
Balance=1000
try:
    Withdraw=float(input())
    if Withdraw <= 0:
        raise ValueError("Please Withdraw amount greater than zero")
    if Withdraw > Balance:
        raise ValueError("The Withdraw amount should be less than Balance")
except ValueError as e:
    print("Negative:",e)
else:
    Current_Balance=Balance-Withdraw
    print(Account_no)
    print(Balance)
    print(Current_Balance)

# %%
#Q26. Catch invalid tenure input for banking case 3; use sample reference ACC-1026 and explain the result.
Account_number="ACC-1026"
Loan_Amount=100000
Tenure=int(input())
try:
    if Tenure <=0 or Tenure>30:
        raise ValueError("Tenure must be between 1 and 30 years")
except ValueError as e:
    print("Tenure Error:",e)
else:
    print("Account Number:",Account_number)
    print("Loan Amount:",Loan_Amount)
    print("Loan Tenurity:",Tenure)

# %%
#Q27.Use else after pin-format validation for banking case 3; use sample reference ACC-1027 and explain the result.
Account_number="ACC-1027"
try :
    pin=input()
    if len(pin) !=4 or not pin.isdigit():
      raise ValueError("The Pin must contain 4 digit Numbers only")
    # if int(pin) != original_pin:
    #    raise ValueError("The Pin is incorrect") 
except ValueError as e:
   print("Invalid Pin:",e)
else:
   print("Account Number:",Account_number)
   print("Pin Format is correct and Successfully logged in")

# %%
#Q28. Use finally to close a session for banking case 3; use sample reference ACC-1028 and explain the result.
Account_number="ACC-1028"
try:
    User_Account_Number=input()
    if User_Account_Number != Account_number:
        raise ValueError("Please enter correct account number")
except ValueError as e:
    print("Invalid Account Number:",e)
else:
    print("Account_number:",User_Account_Number)
finally:
    print("Thank You for banking with us")

# %%
#Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference ACC-1029 and explain the result.
Account_number="ACC-1029"
Balance=10000

try:
    Withdraw=int(input())
    if Withdraw<=0:
            raise ValueError("Withdraw must be greater than zero")
    if Withdraw >= Balance:
        raise ValueError("Withdraw amount must be less than Available Balance")
except ValueError as v:
    print("Invalid Withdraw:",v)
else:
    New_balance = Balance-Withdraw 
    print("Account Number:",Account_number)
    print("Balance:",Balance)
    print("Withdraw Amount is:",Withdraw)
    print("New Balance is:",New_balance)
# Out:
# Invalid Withdraw: Withdraw amount must be less than Available Balance

# %%
#Q30. Raise a clear valueerror for banking case 3; use sample reference ACC-1030 and explain the result.
Account_no="ACC-1030"
Account_number=input("Enter Account number")
try:
    if Account_number != Account_no:
        raise ValueError("The Account number should contain 3 capital alphabets with special character - including 4 digits")
except ValueError as e:
    print("Please Check:",e)
else:
    print(Account_number)
    print("You have entered Valid Account number")

# %% [markdown]
# **Medium**

# %%
#Q31. Create insufficientfundserror for banking case 1; use sample reference ACC-1031 and explain the result.
class Insufficientfundserror(Exception):
  message="Insufficientfundserror"
Account_no="ACC-1031"
Balance=200
try:
    transfer_amount=float(input())
    if transfer_amount <=0:
        raise Insufficientfundserror("The Transfer Amount should be greater than zero")
    if transfer_amount >Balance:
        raise Insufficientfundserror("The  Balance is insufficient ")
except Insufficientfundserror as e:
    print("Insufficient Fund Error:",e)    
else:
    New_balance=Balance-transfer_amount
    print("Account Number:",Account_no)
    print("Balance:",Balance)  
    print("Transfer Amount:",transfer_amount)  
    print("New Balance is:",New_balance)
# Out:
# Insufficient Fund Error: The Transfer Amount should be greater than zero

# %%
#Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference ACC-1032 and explain the result.
class Invalidytransactionerror(ValueError):
    message="Invalid Transaction Type"
Account_number="ACC-1032"
Transaction_Type=["UPI","Credit Card","Debit Card"]
User_Transaction_type=input()
try:
    if User_Transaction_type not in Transaction_Type:
        raise Invalidytransactionerror("Please select only from:",Transaction_Type)
except Invalidytransactionerror as i:
    print("Invalid Transaction Error:",i)
else:
    print("Account Number:",Account_number)
    print("User Transaction Type:",User_Transaction_type)
# Out:
# Account Number: ACC-1032
# User Transaction Type: Credit Card

# %%
#Q33. Process transfers while isolating bad rows for banking case 1; use sample reference ACC-1033 and explain the result.
Account={
    "Account_no":["ACC-1031","ACC-1032","ACC-1033"],
    "Balance":[200,-300,500]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
  except ValueError as e:
    print(Account["Account_no"][i],j, "Invalid:", e)
    continue 
  else:
        print(Account["Account_no"][i],j)
# Out:
# ACC-1031 200
# ACC-1032 -300 Invalid: Incorrect Value
# ACC-1033 500

# %%
#Q34. Retry a transient payment gateway for banking case 1; use sample reference ACC-1034 and explain the result.
Account="ACC-1034"
Balance=1000
max_length=5
for i in range(4,max_length+2):
    try:
        if i > max_length:
            raise ValueError("Please try again Later")
    except ValueError as e:
        print("Retry:",e)
    else:
        print("Account Number:",Account)
        print("Balance:",Balance)
# Out:
# Account Number: ACC-1034
# Balance: 1000
# Account Number: ACC-1034
# Balance: 1000
# Retry: Please try again Later

# %%
#Q35. Log failed standing instructions for banking case 1; use sample reference ACC-1035 and explain the result.
Info={
    "Account_Number":"ACC-1035",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
# Out:
# Account Number: ACC-1035
# Balance: 1000
# Status:Success
# Current Balance: 200

# %%
#Q36. Return a structured failure result for banking case 1; use sample reference ACC-1036 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1036",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
    print("Transaction_ID:", "TXN12345")
    print("Timestamp:", datetime.datetime.now().isoformat())
# Out:
# Account Number: ACC-1036
# Balance: 1000
# Status:Success
# Current Balance: 800
# Transaction_ID: TXN12345
# Timestamp: 2026-09-04T13:58:36.672676

# %%
#Q37. Validate a nested beneficiary record for banking case 1; use sample reference ACC-1037 and explain the result.
Beneficiary_Info={
    "Name":"Ramya",
    "Account":{"Account_Number":"ACC-1037","Bank":"HDFC"},
    "IFSC":"HDFC12345678"
}
Account_Holder_Name=input()
Account_number=input()
Bank_Name=input()
IFSC_code=input()
try:
    if Account_Holder_Name.lower() !=Beneficiary_Info["Name"].lower():
        raise ValueError("Please enter Valid Holder Name")
    if Account_number != Beneficiary_Info["Account"]["Account_Number"]:
        raise ValueError("The Accoount Number is incorrect")
    if Bank_Name.lower() != Beneficiary_Info["Account"]["Bank"].lower():
        raise ValueError("You have entered Incorrect Bank Name")
    if IFSC_code !=Beneficiary_Info["IFSC"]:
        raise ValueError("Please give proper IFSC code")
except ValueError as e:
    print("Invalid:",e)
else:
    print("Beneficiary Information is Correct")
# Out:
# Invalid: Please enter Valid Holder Name

# %%
#Q38. Use a context manager for an audit file for banking case 1; use sample reference ACC-1038 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1038",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    with open("audit.txt","w") as f:
     f.write(f"Account Number:{Info["Account_Number"]} ,") 
     f.write(f"Balance:{Info["Balance"]} ,")
     f.write(f"Status:{Info["Status"]} ,")
     f.write(f"Reason:{e} ,")
     f.write(f"Timestamp: {datetime.datetime.now().isoformat()} ,")
else:
    with open("audit.txt","w") as f:
     Current_Balance=Info["Balance"]-transfer_amount
     f.write(f"Account Number:{Info["Account_Number"]}, ") 
     f.write(f"Balance:{Info["Balance"]} ,") 
     f.write("Status:Success ,")
     f.write(f"Current Balance:{Current_Balance}, ")
     f.write(f"Transaction_ID: TXN12345 ,")
     f.write(f"Timestamp:{datetime.datetime.now().isoformat()}")
with open("audit.txt","r") as f:
    data=f.read()
    print(data)
# Out:
# Account Number:ACC-1036 ,Balance:1000 ,Status:Failed ,Reason:Insufficient Balance ,Timestamp: 2026-09-04T14:33:30.098319 ,

# %%
#Q39. Separate validation and recovery for banking case 1; use sample reference ACC-1039 and explain the result.
Info={
    "Account_Number":"ACC-1039",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
transfer_amount=int(input())
def Validation():
     if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
     if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
def Recovery():
   try:
      Validation()     
   except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
   else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
Recovery()
# Out:
# Account Number: ACC-1035
# Balance: 1000
# Status: Failed
# Reason: Insufficient Balance

# %%
#Q40. Collect all kyc validation errors for banking case 1; use sample reference ACC-1040 and explain the result.
Account_number=input()
First_Name=input()
Last_Name=input()
Phone_Number=(input())
errors=[]
try:
    if Account_number.strip() == "":
        errors.append("Account Number must be filled")
    if First_Name.strip() == "":
       errors.append("Please Fill First Name")
    if Last_Name.strip() == "":
       errors.append("Please fill the Last Name")
    if Phone_Number.strip() == "":
       errors.append("Please fill Phone Number")
    if errors:
       raise ValueError ("KYC Validation Failed")  
except :
    print("KYC Validation Errors for Account: ACC-1040")
    for err in errors:
        print("-", err) 
else:
    print("KYC Completed for ",Account_number)
# Out:
# KYC Completed for  ACC-1040

# %%
#Q41. Create insufficientfundserror for banking case 2; use sample reference ACC-1041 and explain the result.
class Insufficientfundserror(Exception):
      message="Insufficientfundserror"
Account_no="ACC-1041"
Balance=200
try:
    transfer_amount=float(input())
    if transfer_amount <=0:
        raise Insufficientfundserror("The Transfer Amount should be greater than zero")
    if transfer_amount >Balance:
        raise Insufficientfundserror("The  Balance is insufficient ")
except Insufficientfundserror as e:
    print("Insufficient Fund Error:",e)    
else:
    New_balance=Balance-transfer_amount
    print("Account Number:",Account_no)
    print("Balance:",Balance)  
    print("Transfer Amount:",transfer_amount)  
    print("New Balance is:",New_balance)

# %%
#Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference ACC-1042 and explain the result.
class Invalidytransactionerror(ValueError):
    message="Invalid Transaction Type"
Account_number="ACC-1042" 
Transaction_Type=["UPI","Credit Card","Debit Card"]
User_Transaction_type=input()
try:
    if User_Transaction_type not in Transaction_Type:
        raise Invalidytransactionerror("Please select only from:",Transaction_Type)
except Invalidytransactionerror as i:
    print("Invalid Transaction Error:",i)
else:
    print("Account Number:",Account_number)
    print("User Transaction Type:",User_Transaction_type)

# %%
#Q43. Process transfers while isolating bad rows for banking case 2; use sample reference ACC-1043 and explain the result.
Account={
    "Account_no":["ACC-1041","ACC-1042","ACC-1043"],
    "Balance":[200,-300,500]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
  except ValueError as e:
    print(Account["Account_no"][i],j, "Invalid:", e)
    continue 
  else:
        print(Account["Account_no"][i],j)

# %%
#Q44. Retry a transient payment gateway for banking case 2; use sample reference ACC-1044 and explain the result.
Account="ACC-1044"
Balance=1000
max_length=5
for i in range(4,max_length+2):
    try:
        if i > max_length:
            raise ValueError("Please try again Later")
    except ValueError as e:
        print("Retry:",e)
    else:
        print("Account Number:",Account)
        print("Balance:",Balance)

# %%
#Q45. Log failed standing instructions for banking case 2; use sample reference ACC-1045 and explain the result.
Info={
    "Account_Number":"ACC-1045",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)

# %%
#Q46. Return a structured failure result for banking case 2; use sample reference ACC-1046 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1046",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
    print("Transaction_ID:", "TXN12345")
    print("Timestamp:", datetime.datetime.now().isoformat())

# %%
#Q47. Validate a nested beneficiary record for banking case 2; use sample reference ACC-1047 and explain the result.
Beneficiary_Info={
    "Name":"Ramya",
    "Account":{"Account_Number":"ACC-1047","Bank":"HDFC"},
    "IFSC":"HDFC12345678"
}
Account_Holder_Name=input()
Account_number=input()
Bank_Name=input()
IFSC_code=input()
try:
    if Account_Holder_Name.lower() !=Beneficiary_Info["Name"].lower():
        raise ValueError("Please enter Valid Holder Name")
    if Account_number != Beneficiary_Info["Account"]["Account_Number"]:
        raise ValueError("The Accoount Number is incorrect")
    if Bank_Name.lower() != Beneficiary_Info["Account"]["Bank"].lower():
        raise ValueError("You have entered Incorrect Bank Name")
    if IFSC_code !=Beneficiary_Info["IFSC"]:
        raise ValueError("Please give proper IFSC code")
except ValueError as e:
    print("Invalid:",e)
else:
    print("Beneficiary Information is Correct")

# %%
#Q48. Use a context manager for an audit file for banking case 2; use sample reference ACC-1048 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1048",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    with open("audit.txt","w") as f:
     f.write(f"Account Number:{Info["Account_Number"]} ,") 
     f.write(f"Balance:{Info["Balance"]} ,")
     f.write(f"Status:{Info["Status"]} ,")
     f.write(f"Reason:{e} ,")
     f.write(f"Timestamp: {datetime.datetime.now().isoformat()} ,")
else:
    with open("audit.txt","w") as f:
     Current_Balance=Info["Balance"]-transfer_amount
     f.write(f"Account Number:{Info["Account_Number"]}, ") 
     f.write(f"Balance:{Info["Balance"]} ,") 
     f.write("Status:Success ,")
     f.write(f"Current Balance:{Current_Balance}, ")
     f.write(f"Transaction_ID: TXN12345 ,")
     f.write(f"Timestamp:{datetime.datetime.now().isoformat()}")
with open("audit.txt","r") as f:
    data=f.read()
    print(data)

# %%
#Q49. Separate validation and recovery for banking case 2; use sample reference ACC-1049 and explain the result.
Info={
    "Account_Number":"ACC-1049",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
transfer_amount=int(input())
def Validation():
     if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
     if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
def Recovery():
   try:
      Validation()     
   except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
   else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
Recovery()

# %%
#Q50. Collect all kyc validation errors for banking case 2; use sample reference ACC-1050 and explain the result.
Account_number=input()
First_Name=input()
Last_Name=input()
Phone_Number=(input())
errors=[]
try:
    if Account_number.strip() == "":
        errors.append("Account Number must be filled")
    if First_Name.strip() == "":
       errors.append("Please Fill First Name")
    if Last_Name.strip() == "":
       errors.append("Please fill the Last Name")
    if Phone_Number.strip() == "":
       errors.append("Please fill Phone Number")
    if errors:
       raise ValueError ("KYC Validation Failed")  
except :
    print("KYC Validation Errors for Account: ACC-1050")
    for err in errors:
        print("-", err) 
else:
    print("KYC Completed for ",Account_number)

# %%
#Q51. Create insufficientfundserror for banking case 3; use sample reference ACC-1051 and explain the result.
class Insufficientfundserror(Exception):
      message="Insufficientfundserror"
Account_no="ACC-1051"
Balance=200
try:
    transfer_amount=float(input())
    if transfer_amount <=0:
        raise Insufficientfundserror("The Transfer Amount should be greater than zero")
    if transfer_amount >Balance:
        raise Insufficientfundserror("The  Balance is insufficient ")
except Insufficientfundserror as e:
    print("Insufficient Fund Error:",e)    
else:
    New_balance=Balance-transfer_amount
    print("Account Number:",Account_no)
    print("Balance:",Balance)  
    print("Transfer Amount:",transfer_amount)  
    print("New Balance is:",New_balance)

# %%
#Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference ACC-1052 and explain the result.
class Invalidytransactionerror(ValueError):
    message="Invalid Transaction Type"
Account_number="ACC-1052" 
Transaction_Type=["UPI","Credit Card","Debit Card"]
User_Transaction_type=input()
try:
    if User_Transaction_type not in Transaction_Type:
        raise Invalidytransactionerror("Please select only from:",Transaction_Type)
except Invalidytransactionerror as i:
    print("Invalid Transaction Error:",i)
else:
    print("Account Number:",Account_number)
    print("User Transaction Type:",User_Transaction_type)

# %%
#Q53. Process transfers while isolating bad rows for banking case 3; use sample reference ACC-1053 and explain the result.
Account={
    "Account_no":["ACC-1051","ACC-1052","ACC-1053"],
    "Balance":[200,-300,500]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
  except ValueError as e:
    print(Account["Account_no"][i],j, "Invalid:", e)
    continue 
  else:
        print(Account["Account_no"][i],j)

# %%
#Q54. Retry a transient payment gateway for banking case 3; use sample reference ACC-1054 and explain the result.
Account="ACC-1054"
Balance=1000
max_length=5
for i in range(4,max_length+2):
    try:
        if i > max_length:
            raise ValueError("Please try again Later")
    except ValueError as e:
        print("Retry:",e)
    else:
        print("Account Number:",Account)
        print("Balance:",Balance)

# %%
#Q55. Log failed standing instructions for banking case 3; use sample reference ACC-1055 and explain the result.
Info={
    "Account_Number":"ACC-1055",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)

# %%
#Q56. Return a structured failure result for banking case 3; use sample reference ACC-1056 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1056",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
    print("Transaction_ID:", "TXN12345")
    print("Timestamp:", datetime.datetime.now().isoformat())

# %%
#Q57. Validate a nested beneficiary record for banking case 3; use sample reference ACC-1057 and explain the result.
Beneficiary_Info={
    "Name":"Ramya",
    "Account":{"Account_Number":"ACC-1057","Bank":"HDFC"},
    "IFSC":"HDFC12345678"
}
Account_Holder_Name=input()
Account_number=input()
Bank_Name=input()
IFSC_code=input()
try:
    if Account_Holder_Name.lower() !=Beneficiary_Info["Name"].lower():
        raise ValueError("Please enter Valid Holder Name")
    if Account_number != Beneficiary_Info["Account"]["Account_Number"]:
        raise ValueError("The Accoount Number is incorrect")
    if Bank_Name.lower() != Beneficiary_Info["Account"]["Bank"].lower():
        raise ValueError("You have entered Incorrect Bank Name")
    if IFSC_code !=Beneficiary_Info["IFSC"]:
        raise ValueError("Please give proper IFSC code")
except ValueError as e:
    print("Invalid:",e)
else:
    print("Beneficiary Information is Correct")

# %%
#Q58. Use a context manager for an audit file for banking case 3; use sample reference ACC-1058 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1058",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    with open("audit.txt","w") as f:
     f.write(f"Account Number:{Info["Account_Number"]} ,") 
     f.write(f"Balance:{Info["Balance"]} ,")
     f.write(f"Status:{Info["Status"]} ,")
     f.write(f"Reason:{e} ,")
     f.write(f"Timestamp: {datetime.datetime.now().isoformat()} ,")
else:
    with open("audit.txt","w") as f:
     Current_Balance=Info["Balance"]-transfer_amount
     f.write(f"Account Number:{Info["Account_Number"]}, ") 
     f.write(f"Balance:{Info["Balance"]} ,") 
     f.write("Status:Success ,")
     f.write(f"Current Balance:{Current_Balance}, ")
     f.write(f"Transaction_ID: TXN12345 ,")
     f.write(f"Timestamp:{datetime.datetime.now().isoformat()}")
with open("audit.txt","r") as f:
    data=f.read()
    print(data)

# %%
#Q59. Separate validation and recovery for banking case 3; use sample reference ACC-1059 and explain the result.
Info={
    "Account_Number":"ACC-1059",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
transfer_amount=int(input())
def Validation():
     if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
     if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
def Recovery():
   try:
      Validation()     
   except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
   else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
Recovery()

# %%
#Q60. Collect all kyc validation errors for banking case 3; use sample reference ACC-1060 and explain the result.Account_number=input()
First_Name=input()
Last_Name=input()
Phone_Number=(input())
errors=[]
try:
    if Account_number.strip() == "":
        errors.append("Account Number must be filled")
    if First_Name.strip() == "":
       errors.append("Please Fill First Name")
    if Last_Name.strip() == "":
       errors.append("Please fill the Last Name")
    if Phone_Number.strip() == "":
       errors.append("Please fill Phone Number")
    if errors:
       raise ValueError ("KYC Validation Failed")  
except :
    print("KYC Validation Errors for Account: ACC-1060")
    for err in errors:
        print("-", err) 
else:
    print("KYC Completed for ",Account_number)

# %%
#Q61. Create insufficientfundserror for banking case 4; use sample reference ACC-1061 and explain the result.
class Insufficientfundserror(Exception):
      message="Insufficientfundserror"
Account_no="ACC-1041"
Balance=200
try:
    transfer_amount=float(input())
    if transfer_amount <=0:
        raise Insufficientfundserror("The Transfer Amount should be greater than zero")
    if transfer_amount >Balance:
        raise Insufficientfundserror("The  Balance is insufficient ")
except Insufficientfundserror as e:
    print("Insufficient Fund Error:",e)    
else:
    New_balance=Balance-transfer_amount
    print("Account Number:",Account_no)
    print("Balance:",Balance)  
    print("Transfer Amount:",transfer_amount)  
    print("New Balance is:",New_balance)

# %%
#Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference ACC-1062 and explain the result.
class Invalidytransactionerror(ValueError):
    message="Invalid Transaction Type"
Account_number="ACC-1042" 
Transaction_Type=["UPI","Credit Card","Debit Card"]
User_Transaction_type=input()
try:
    if User_Transaction_type not in Transaction_Type:
        raise Invalidytransactionerror("Please select only from:",Transaction_Type)
except Invalidytransactionerror as i:
    print("Invalid Transaction Error:",i)
else:
    print("Account Number:",Account_number)
    print("User Transaction Type:",User_Transaction_type)

# %%
#Q63. Process transfers while isolating bad rows for banking case 4; use sample reference ACC-1063 and explain the result.
Account={
    "Account_no":["ACC-1051","ACC-1052","ACC-1053"],
    "Balance":[200,-300,500]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
  except ValueError as e:
    print(Account["Account_no"][i],j, "Invalid:", e)
    continue 
  else:
        print(Account["Account_no"][i],j)
# Out:
# ACC-1051 200
# ACC-1052 -300 Invalid: Incorrect Value
# ACC-1053 500

# %%
#Q64. Retry a transient payment gateway for banking case 4; use sample reference ACC-1064 and explain the result.
Account="ACC-1054"
for i in range(3):
    try:
        if i  < 2:
            raise ConnectionError("Please try again")
        print("Payment Successful")
        break
        
    except ConnectionError as e:
        print("Retry:",i+1,"-",e)
# Out:
# Retry: 1 - Please try again
# Retry: 2 - Please try again
# Payment Successful

# %%
#Q65. Log failed standing instructions for banking case 4; use sample reference ACC-1065 and explain the result.
Info={
    "Account_Number":"ACC-1065",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)

# %%
# Q66. Return a structured failure result for banking case 4; use sample reference ACC-1066 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1066",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
    print("Transaction_ID:", "TXN12345")
    print("Timestamp:", datetime.datetime.now().isoformat())

# %%
# Q67. Validate a nested beneficiary record for banking case 4; use sample reference ACC-1067 and explain the result.
Beneficiary_Info={
    "Name":"Ramya",
    "Account":{"Account_Number":"ACC-1067","Bank":"HDFC"},
    "IFSC":"HDFC12345678"
}
Account_Holder_Name=input()
Account_number=input()
Bank_Name=input()
IFSC_code=input()
try:
    if Account_Holder_Name.lower() !=Beneficiary_Info["Name"].lower():
        raise ValueError("Please enter Valid Holder Name")
    if Account_number != Beneficiary_Info["Account"]["Account_Number"]:
        raise ValueError("The Accoount Number is incorrect")
    if Bank_Name.lower() != Beneficiary_Info["Account"]["Bank"].lower():
        raise ValueError("You have entered Incorrect Bank Name")
    if IFSC_code !=Beneficiary_Info["IFSC"]:
        raise ValueError("Please give proper IFSC code")
except ValueError as e:
    print("Invalid:",e)
else:
    print("Beneficiary Information is Correct")

# %%
# Q68. Use a context manager for an audit file for banking case 4; use sample reference ACC-1068 and explain the result.
import datetime
Info={
    "Account_Number":"ACC-1068",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
try:
    transfer_amount=int(input())
    if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
    if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
except ValueError as e:
    with open("audit.txt","w") as f:
     f.write(f"Account Number:{Info["Account_Number"]} ,") 
     f.write(f"Balance:{Info["Balance"]} ,")
     f.write(f"Status:{Info["Status"]} ,")
     f.write(f"Reason:{e} ,")
     f.write(f"Timestamp: {datetime.datetime.now().isoformat()} ,")
else:
    with open("audit.txt","w") as f:
     Current_Balance=Info["Balance"]-transfer_amount
     f.write(f"Account Number:{Info["Account_Number"]}, ") 
     f.write(f"Balance:{Info["Balance"]} ,") 
     f.write("Status:Success ,")
     f.write(f"Current Balance:{Current_Balance}, ")
     f.write(f"Transaction_ID: TXN12345 ,")
     f.write(f"Timestamp:{datetime.datetime.now().isoformat()}")
with open("audit.txt","r") as f:
    data=f.read()
    print(data)

# %%
# Q69. Separate validation and recovery for banking case 4; use sample reference ACC-1069 and explain the result.
Info={
    "Account_Number":"ACC-1069",
    "Balance":1000,
    "Status":"Failed",
    "Reason":"Insufficient Balance"
}
transfer_amount=int(input())
def Validation():
     if transfer_amount <=0:
        raise ValueError("Please Transfer greater than 0")
     if transfer_amount > Info["Balance"]:
        raise ValueError("Insufficient Balance")
def Recovery():
   try:
      Validation()     
   except ValueError as e:
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"])
    print("Status:",Info["Status"])
    print("Reason:",e)
   else:
    Current_Balance=Info["Balance"]-transfer_amount
    print("Account Number:",Info["Account_Number"]) 
    print("Balance:",Info["Balance"]) 
    print("Status:Success")
    print("Current Balance:",Current_Balance)
Recovery()
# Out:
# Account Number: ACC-1069
# Balance: 1000
# Status:Success
# Current Balance: 800

# %%
# Q70. Collect all kyc validation errors for banking case 4; use sample reference ACC-1070 and explain the result.
Account_number=input()
First_Name=input()
Last_Name=input()
Phone_Number=(input())
errors=[]
try:
    if Account_number.strip() == "":
        errors.append("Account Number must be filled")
    if First_Name.strip() == "":
       errors.append("Please Fill First Name")
    if Last_Name.strip() == "":
       errors.append("Please fill the Last Name")
    if Phone_Number.strip() == "":
       errors.append("Please fill Phone Number")
    if errors:
       raise ValueError ("KYC Validation Failed")  
except :
    print("KYC Validation Errors for Account: ACC-1070")
    for err in errors:
        print("\n", err) 
else:
    print("KYC Completed for ",Account_number)
# Out:
# KYC Validation Errors for Account: ACC-1070
#
#  Please fill the Last Name
#
#  Please fill Phone Number

# %% [markdown]
# **Difficult**

# %%
#Q71. Design a banking exception hierarchy for banking case 1; use sample reference ACC-1071 and explain the result.
Info={"Account_Number":"ACC-1071","First_Name":"Ramya"}
class BankingException(Exception):
   def Validation(self,account_number,first_Name):
      if account_number != Info["Account_Number"]:
             raise ValueError ("Account Number is not found")
      if first_Name.lower() != Info["First_Name"].lower():
              raise ValueError ("Missmatch Name") 
class TransactionException(BankingException):
   def Transaction(self,account_number,first_Name,Balance,transfer_amount):
      self.Validation(account_number,first_Name)
      self.transfer_amount = int(input())
      if transfer_amount >Balance:
         raise ValueError("Insufficient Balance")
      if transfer_amount >100000:
         raise ValueError("Transfer amount exceeds allowed limit")   
class KYCValidation(BankingException):
   def KYC(self,account_number,first_Name):
      self.Validation(account_number,first_Name)
      if Account_number.strip() == "":
         errors.append("Account Number must be filled")
      if First_Name.strip() == "":
         errors.append("Please Fill First Name")  
#Input
account_number=input()
first_name=input()
transfer_amount=int(input())
try: 
   kyc = KYCValidation() 
   kyc.KYC(account_number, first_name)
   print("KYC completed for:", account_number) 

   txn=TransactionException()
   txn.Transaction(account_number,first_name,5000)
   print("Transaction Successful")
except ValueError as e: 
   print("Error:", e)
# Out:
# Error: Account Number is not found

# %%
#Q72. Make a transfer rollback-safe for banking case 1; use sample reference ACC-1072 and explain the result.
source={
    "Account_number":"ACC-1071",
    "Balance":1000
}
Beneficiary={
    "Account_number":"ACC-1072",
    "Balance":0
}
transfer_amount=int(input())
try:
    if transfer_amount <=0:raise ValueError("Transfer amount should be greater than 0")
    if transfer_amount > source["Balance"]:raise ValueError ("Insufficient Balance")
    if transfer_amount >10000:raise ValueError ("Transfer amount should not exceed the limit")
    current_source_balance=source["Balance"]-transfer_amount
    current_beneficiary_balance=Beneficiary["Balance"]+transfer_amount
    print("Transfer successful")
    print("After Transaction Sender Balance:",current_source_balance)
    print("After Transaction Receivers Balance :",current_beneficiary_balance) 
except ValueError as e:
    print("Account Number:",Beneficiary["Account_number"])
    print("Transaction Failed:",e)
    print("Transaction Rolled Back")
    print("After Transaction Sender Balance:",source["Balance"])
    print("After Transaction Receivers Balance :",Beneficiary["Balance"])
# Out:
# Account Number: ACC-1072
# Transaction Failed: Insufficient Balance
# Transaction Rolled Back
# After Transaction Sender Balance: 1000
# After Transaction Receivers Balance : 0

# %%
#Q73. Preserve causes across service layers for banking case 1; use sample reference ACC-1073 and explain the result.
source={"Account_number":"ACC-1072","Balance":1000}
Beneficiary={"Account_number":"ACC-1073","Balance":100}
amount = int(input())
try:
    if amount <=0: raise ValueError("Amount should be >0")
    if amount >source["Balance"]: raise ValueError ("Insufficcient Balance")
    if amount > 100000:raise ValueError("Limit Exceeded")
    source["Balance"] -= amount
    Beneficiary["Balance"]+=amount
    print("Transfer Successful","\n","Current Sender Balance:",source["Balance"],"\n","Current Beneficiary Balance:",Beneficiary["Balance"])
except ValueError as e:
    print("Transaction Failed in service layer:",e)
# Out:
# Transaction Failed in service layer: Insufficcient Balance

# %%
#Q74. Implement bounded exponential retry for banking case 1; use sample reference ACC-1074 and explain the result.
import time
Account_number="ACC-1074"
delay=2
for i in range(3):
    try:
        if i<2:
            raise ConnectionError("Please try again")
        print("Payment Successful to Account:",Account_number)
    except ConnectionError as c:
        print("Retry:",i+1,"-",c)
        time.sleep(delay)
        delay *= 2
# Out:
# Retry: 1 - Please try again
# Retry: 2 - Please try again
# Payment Successful to Account: ACC-1074

# %%
#Q75. Create a transaction context manager for banking case 1; use sample reference ACC-1075 and explain the result.
source={"Account_number":"ACC-1074","Balance":1000}
Beneficiary={"Account_number":"ACC-1075","Balance":0}
amount=int(input())
class Transaction():
    def __init__(self,source_acc,beneficiary_acc,source_balance,beneficiary_balance):
        self.source = {"Account_number": source_acc, "Balance": source_balance}
        self.beneficiary = {"Account_number": beneficiary_acc, "Balance": beneficiary_balance}
    def Validation(self,amount):
        if amount <= 0:raise ValueError("Amount must be > 0")
        if amount > self.source["Balance"]:raise ValueError("Insufficient Balance")
    def Recovery(self,amount):     
      try:
            self.Validation(amount)
            # perform transfer
            self.source["Balance"] -= amount
            self.beneficiary["Balance"] += amount
            print("Transaction Successful")
            print("Sender Balance:", self.source["Balance"])
            print("Beneficiary Balance:", self.beneficiary["Balance"])
            print("Transaction Committed")
            print("Transaction Closed")
      except ValueError as e:
            print("Transaction Failed:", e)
            print("Transaction Rolled Back")
            print("Sender Balance:", self.source["Balance"])
            print("Beneficiary Balance:", self.beneficiary["Balance"])
t = Transaction("ACC-1071", "ACC-1075", source["Balance"], Beneficiary["Balance"])
t.Recovery(amount)
# Out:
# Transaction Failed: Insufficient Balance
# Transaction Rolled Back
# Sender Balance: 1000
# Beneficiary Balance: 0

# %%
source={"Account_number":"ACC-1071","Balance":1000}
Beneficiary={"Account_number":"ACC-1075","Balance":0}
amount=200

def Validation(source, Beneficiary, amount):
    if amount <= 0:
        raise ValueError("Amount must be > 0")
    if amount > source["Balance"]:
        raise ValueError("Insufficient Balance")

def Recovery(source, Beneficiary, amount):
    try:
        Validation(source, Beneficiary, amount)
        # perform transfer
        source["Balance"] -= amount
        Beneficiary["Balance"] += amount
        print("Transaction Successful")
        print("Sender Balance:", source["Balance"])
        print("Beneficiary Balance:", Beneficiary["Balance"])
    except ValueError as e:
        print("Transaction Failed:", e)
        print("Transaction Rolled Back")
        print("Sender Balance:", source["Balance"])
        print("Beneficiary Balance:", Beneficiary["Balance"])

# Run transaction
Recovery(source, Beneficiary, amount)

# %%
#Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference ACC-1076 and explain the result.
dlq=[]
import time
Account_number="ACC-1076"
payment=[{"ID":101,"Balance":500},{"ID":102,"Balance":-200}]
for i in payment:
    try:
        if i["Balance"]<=2:
            raise ConnectionError("Invalid Payment")
        print("Payment Processed for ID :",i["ID"])
    except ConnectionError as c:
        print("Payment Failed for ID:",i["ID"])
        dlq.append({"Account number":Account_number,"ID":i["ID"],"Balance":i["Balance"],"Payment Failed":c})
        time.sleep(2)
print("Dead Letter queue:",dlq)
# Out:
# Payment Processed for ID : 101
# Payment Failed for ID: 102
# Dead Letter queue: [{'Account number': 'ACC-1074', 'ID': 102, 'Balance': -200, 'Payment Failed': ConnectionError('Invalid Payment')}]

# %%
#Q77. Make batch settlement failure-isolated for banking case 1; use sample reference ACC-1077 and explain the result.
Account={
    "Account_no":["ACC-1071","ACC-1072","ACC-1073","ACC-1074","ACC-1075","ACC-1076","ACC-1077"],
    "Balance":[200,-300,500,100,1000,-900,0]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
    print(Account["Account_no"][i],"\n","Amount","-",j,"\n","Settlement Successful","\n")
  except ValueError as e:
    print(Account["Account_no"][i],"\n","Amount:",j, "\n","Settlement Failed:", e,"\n")
    continue
# Out:
# ACC-1071
#  Amount - 200
#  Settlement Successful
#
# ACC-1072
#  Amount: -300
#  Settlement Failed: Incorrect Value
#
# ACC-1073
#  Amount - 500
#  Settlement Successful
#
# ACC-1074
#  Amount - 100
#  Settlement Successful
#
# ACC-1075
#  Amount - 1000
#  Settlement Successful
#
# ACC-1076
#  Amount: -900
#  Settlement Failed: Incorrect Value
#
# ACC-1077
#  Amount: 0
#  Settlement Failed: Incorrect Value

# %%
#Q78. Report exact paths in nested statements for banking case 1; use sample reference ACC-1078 and explain the result.
Customers={
    "Account_number":{"Account1":{"ACC-1078":{"Transactions":[200,-300,-400,0]}}}
}
for i, j in Customers["Account_number"].items():
    for k, v in j.items():
        for l,m  in enumerate(v["Transactions"]):
            try:
                if m <= 0:raise ValueError("Invalid transaction")
            except ValueError as e:
                print(
                    "Path: Account_number ->",
                    m, "->",
                    k, "-> Transactions ->",
                    i,
                    ":", e
                )
# Out:
# Path: Account_number -> -300 -> ACC-1078 -> Transactions -> Account1 : Invalid transaction
# Path: Account_number -> -400 -> ACC-1078 -> Transactions -> Account1 : Invalid transaction
# Path: Account_number -> 0 -> ACC-1078 -> Transactions -> Account1 : Invalid transaction

# %% [markdown]
# **Q79. Design idempotent recovery after timeout for banking case 1; use sample reference ACC-1079 and explain the result.**

# %%
Account_number="ACC-1079"
processed_time={"TXN-1010"}
txn=input()
try:
    if txn in processed_time:
        print(f"{txn} is already processed for {Account_number}-duplicates not allowed")
    else:
        raise TimeoutError("Payment Time Out")
except TimeoutError as t:
    print("Retrying payment") 
#     processed_time.add(txn)
# Out:
# TXN-1010 is already processed for ACC-1079-duplicates not allowed

# %% [markdown]
# Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference ACC-1080 and explain the result.

# %%
Account_number="ACC-1080"
Bank_records=[200,500,700,800,900,200]
payment_records=[200,500,900,800,700,1200]
for i,j in enumerate(Bank_records):
  try: 
    if j == payment_records[i]:
        print(f"{j} Matched")
    else:
        raise ValueError(f"{j} MissMatch")  
  except ValueError as e:
     print("Error:",e)
# Out:
# 200 Matched
# 500 Matched
# Error: 700 MissMatch
# 800 Matched
# Error: 900 MissMatch
# Error: 200 MissMatch

# %% [markdown]
# Q81. Design a banking exception hierarchy for banking case 2; use sample reference ACC-1081 and explain the result.

# %%
Info={"Account_Number":"ACC-1081", "First_Name":"Ramya"}
class BankingException(Exception):
   def Validation(self,account_number,first_Name):
      if account_number != Info["Account_Number"]:
             raise ValueError ("Account Number is not found")
      if first_Name.lower() != Info["First_Name"].lower():
              raise ValueError ("Missmatch Name") 
class TransactionException(BankingException):
   def Transaction(self,account_number,first_Name,Balance,transfer_amount):
      self.Validation(account_number,first_Name)
      self.transfer_amount = int(input())
      if transfer_amount >Balance:
         raise ValueError("Insufficient Balance")
      if transfer_amount >100000:
         raise ValueError("Transfer amount exceeds allowed limit")   
class KYCValidation(BankingException):
   def KYC(self,account_number,first_Name):
      self.Validation(account_number,first_Name)
      if Account_number.strip() == "":
         errors.append("Account Number must be filled")
      if First_Name.strip() == "":
         errors.append("Please Fill First Name")  
#Input
account_number=input()
first_name=input()
transfer_amount=int(input())
try: 
   kyc = KYCValidation() 
   kyc.KYC(account_number, first_name)
   print("KYC completed for:", account_number) 

   txn=TransactionException()
   txn.Transaction(account_number,first_name,5000)
   print("Transaction Successful")
except ValueError as e: 
   print("Error:", e)

# %% [markdown]
# Q82. Make a transfer rollback-safe for banking case 2; use sample reference ACC-1082 and explain the result

# %%
source={
    "Account_number":"ACC-1081",
    "Balance":1000
}
Beneficiary={
    "Account_number":"ACC-1082",
    "Balance":0
}
transfer_amount=int(input())
try:
    if transfer_amount <=0:raise ValueError("Transfer amount should be greater than 0")
    if transfer_amount > source["Balance"]:raise ValueError ("Insufficient Balance")
    if transfer_amount >10000:raise ValueError ("Transfer amount should not exceed the limit")
    current_source_balance=source["Balance"]-transfer_amount
    current_beneficiary_balance=Beneficiary["Balance"]+transfer_amount
    print("Transfer successful")
    print("After Transaction Sender Balance:",current_source_balance)
    print("After Transaction Receivers Balance :",current_beneficiary_balance) 
except ValueError as e:
    print("Account Number:",Beneficiary["Account_number"])
    print("Transaction Failed:",e)
    print("Transaction Rolled Back")
    print("After Transaction Sender Balance:",source["Balance"])
    print("After Transaction Receivers Balance :",Beneficiary["Balance"])

# %% [markdown]
# Q83. Preserve causes across service layers for banking case 2; use sample reference ACC-1083 and explain the result.

# %%
source={"Account_number":"ACC-1082","Balance":1000}
Beneficiary={"Account_number":"ACC-1083","Balance":100}
amount = int(input())
try:
    if amount <=0: raise ValueError("Amount should be >0")
    if amount >source["Balance"]: raise ValueError ("Insufficcient Balance")
    if amount > 100000:raise ValueError("Limit Exceeded")
    source["Balance"] -= amount
    Beneficiary["Balance"]+=amount
    print("Transfer Successful","\n","Current Sender Balance:",source["Balance"],"\n","Current Beneficiary Balance:",Beneficiary["Balance"])
except ValueError as e:
    print("Transaction Failed in service layer:",e)

# %% [markdown]
# Q84. Implement bounded exponential retry for banking case 2; use sample reference ACC-1084 and explain the result.

# %%
import time
Account_number="ACC-1084"
delay=2
for i in range(3):
    try:
        if i<2:
            raise ConnectionError("Please try again")
        print("Payment Successful to Account:",Account_number)
    except ConnectionError as c:
        print("Retry:",i+1,"-",c)
        time.sleep(delay)
        delay *= 2

# %% [markdown]
# Q85. Create a transaction context manager for banking case 2; use sample reference ACC-1085 and explain the result.

# %%
source={"Account_number":"ACC-1084","Balance":1000}
Beneficiary={"Account_number":"ACC-1085","Balance":0}
amount=int(input())
class Transaction():
    def __init__(self,source_acc,beneficiary_acc,source_balance,beneficiary_balance):
        self.source = {"Account_number": source_acc, "Balance": source_balance}
        self.beneficiary = {"Account_number": beneficiary_acc, "Balance": beneficiary_balance}
    def Validation(self,amount):
        if amount <= 0:raise ValueError("Amount must be > 0")
        if amount > self.source["Balance"]:raise ValueError("Insufficient Balance")
    def Recovery(self,amount):     
      try:
            self.Validation(amount)
            # perform transfer
            self.source["Balance"] -= amount
            self.beneficiary["Balance"] += amount
            print("Transaction Successful")
            print("Sender Balance:", self.source["Balance"])
            print("Beneficiary Balance:", self.beneficiary["Balance"])
            print("Transaction Committed")
            print("Transaction Closed")
      except ValueError as e:
            print("Transaction Failed:", e)
            print("Transaction Rolled Back")
            print("Sender Balance:", self.source["Balance"])
            print("Beneficiary Balance:", self.beneficiary["Balance"])
t = Transaction("ACC-1071", "ACC-1075", source["Balance"], Beneficiary["Balance"])
t.Recovery(amount)

# %% [markdown]
# Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference ACC-1086 and explain the result.

# %%
dlq=[]
import time
Account_number="ACC-1086"
payment=[{"ID":101,"Balance":500},{"ID":102,"Balance":-200}]
for i in payment:
    try:
        if i["Balance"]<=2:
            raise ConnectionError("Invalid Payment")
        print("Payment Processed for ID :",i["ID"])
    except ConnectionError as c:
        print("Payment Failed for ID:",i["ID"])
        dlq.append({"Account number":Account_number,"ID":i["ID"],"Balance":i["Balance"],"Payment Failed":c})
        time.sleep(2)
print("Dead Letter queue:",dlq)

# %% [markdown]
# Q87. Make batch settlement failure-isolated for banking case 2; use sample reference ACC-1087 and explain the result.

# %%
Account={
    "Account_no":["ACC-1081","ACC-1082","ACC-1083","ACC-1084","ACC-1085","ACC-1086","ACC-1087"],
    "Balance":[200,-300,500,100,1000,-900,0]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
    print(Account["Account_no"][i],"\n","Amount","-",j,"\n","Settlement Successful","\n")
  except ValueError as e:
    print(Account["Account_no"][i],"\n","Amount:",j, "\n","Settlement Failed:", e,"\n")
    continue

# %% [markdown]
# Q88. Report exact paths in nested statements for banking case 2; use sample reference ACC-1088 and explain the result.

# %%
Customers={
    "Account_number":{"Account1":{"ACC-1088":{"Transactions":[200,-300,-400,0]}}}
}
for i, j in Customers["Account_number"].items():
    for k, v in j.items():
        for l,m  in enumerate(v["Transactions"]):
            try:
                if m <= 0:raise ValueError("Invalid transaction")
            except ValueError as e:
                print(
                    "Path: Account_number ->",
                    m, "->",
                    k, "-> Transactions ->",
                    i,
                    ":", e
                )
# Out:
# Path: Account_number -> -300 -> ACC-1088 -> Transactions -> Account1 : Invalid transaction
# Path: Account_number -> -400 -> ACC-1088 -> Transactions -> Account1 : Invalid transaction
# Path: Account_number -> 0 -> ACC-1088 -> Transactions -> Account1 : Invalid transaction

# %% [markdown]
# Q89. Design idempotent recovery after timeout for banking case 2; use sample reference ACC-1089 and explain the result.

# %%
Account_number="ACC-1089"
processed_time={"TXN-1010"}
txn=input()
try:
    if txn in processed_time:
        print(f"{txn} is already processed for {Account_number}-duplicates not allowed")
    else:
        raise TimeoutError("Payment Time Out")
except TimeoutError as t:
    print("Retrying payment") 
#     processed_time.add(txn)
# Out:
# TXN-1010 is already processed for ACC-1089-duplicates not allowed

# %% [markdown]
# Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference ACC-1090 and explain the result.

# %%
Account_number="ACC-1090"
Bank_records=[200,500,700,800,900,200]
payment_records=[200,500,900,800,700,1200]
for i,j in enumerate(Bank_records):
  try: 
    if j == payment_records[i]:
        print(f"{j} Matched")
    else:
        raise ValueError(f"{j} MissMatch")  
  except ValueError as e:
     print("Error:",e)
# Out:
# 200 Matched
# 500 Matched
# Error: 700 MissMatch
# 800 Matched
# Error: 900 MissMatch
# Error: 200 MissMatch

# %% [markdown]
# Q91. Design a banking exception hierarchy for banking case 3; use sample reference ACC-1091 and explain the result.

# %%
Info={"Account_Number":"ACC-1091","First_Name":"Ramya"}
class BankingException(Exception):
   def Validation(self,account_number,first_Name):
      if account_number != Info["Account_Number"]:
             raise ValueError ("Account Number is not found")
      if first_Name.lower() != Info["First_Name"].lower():
              raise ValueError ("Missmatch Name") 
class TransactionException(BankingException):
   def Transaction(self,account_number,first_Name,Balance,transfer_amount):
      self.Validation(account_number,first_Name)
      self.transfer_amount = int(input())
      if transfer_amount >Balance:
         raise ValueError("Insufficient Balance")
      if transfer_amount >100000:
         raise ValueError("Transfer amount exceeds allowed limit")   
class KYCValidation(BankingException):
   def KYC(self,account_number,first_Name):
      self.Validation(account_number,first_Name)
      if Account_number.strip() == "":
         errors.append("Account Number must be filled")
      if First_Name.strip() == "":
         errors.append("Please Fill First Name")  
#Input
account_number=input()
first_name=input()
transfer_amount=int(input())
try: 
   kyc = KYCValidation() 
   kyc.KYC(account_number, first_name)
   print("KYC completed for:", account_number) 

   txn=TransactionException()
   txn.Transaction(account_number,first_name,5000)
   print("Transaction Successful")
except ValueError as e: 
   print("Error:", e)
# Out:
# Error: Account Number is not found

# %% [markdown]
# Q92. Make a transfer rollback-safe for banking case 3; use sample reference ACC-1092 and explain the result.

# %%
source={
    "Account_number":"ACC-1091",
    "Balance":1000
}
Beneficiary={
    "Account_number":"ACC-1092",
    "Balance":0
}
transfer_amount=int(input())
try:
    if transfer_amount <=0:raise ValueError("Transfer amount should be greater than 0")
    if transfer_amount > source["Balance"]:raise ValueError ("Insufficient Balance")
    if transfer_amount >10000:raise ValueError ("Transfer amount should not exceed the limit")
    current_source_balance=source["Balance"]-transfer_amount
    current_beneficiary_balance=Beneficiary["Balance"]+transfer_amount
    print("Transfer successful")
    print("After Transaction Sender Balance:",current_source_balance)
    print("After Transaction Receivers Balance :",current_beneficiary_balance) 
except ValueError as e:
    print("Account Number:",Beneficiary["Account_number"])
    print("Transaction Failed:",e)
    print("Transaction Rolled Back")
    print("After Transaction Sender Balance:",source["Balance"])
    print("After Transaction Receivers Balance :",Beneficiary["Balance"])
# Out:
# Transfer successful
# After Transaction Sender Balance: 800
# After Transaction Receivers Balance : 200

# %% [markdown]
# Q93. Preserve causes across service layers for banking case 3; use sample reference ACC-1093 and explain the result.

# %%
#Q73. Preserve causes across service layers for banking case 1; use sample reference ACC-1073 and explain the result.
source={"Account_number":"ACC-1092","Balance":1000}
Beneficiary={"Account_number":"ACC-1093","Balance":100}
amount = int(input())
try:
    if amount <=0: raise ValueError("Amount should be >0")
    if amount >source["Balance"]: raise ValueError ("Insufficcient Balance")
    if amount > 100000:raise ValueError("Limit Exceeded")
    source["Balance"] -= amount
    Beneficiary["Balance"]+=amount
    print("Transfer Successful","\n","Current Sender Balance:",source["Balance"],"\n","Current Beneficiary Balance:",Beneficiary["Balance"])
except ValueError as e:
    print("Transaction Failed in service layer:",e)
# Out:
# Transfer Successful
#  Current Sender Balance: 800
#  Current Beneficiary Balance: 300

# %% [markdown]
# Q94. Implement bounded exponential retry for banking case 3; use sample reference ACC-1094 and explain the result.

# %%
#Q74. Implement bounded exponential retry for banking case 1; use sample reference ACC-1074 and explain the result.
import time
Account_number="ACC-1094"
delay=2
for i in range(3):
    try:
        if i<2:
            raise ConnectionError("Please try again")
        print("Payment Successful to Account:",Account_number)
    except ConnectionError as c:
        print("Retry:",i+1,"-",c)
        time.sleep(delay)
        delay *= 2
# Out:
# Retry: 1 - Please try again
# Retry: 2 - Please try again
# Payment Successful to Account: ACC-1094

# %% [markdown]
# Q95. Create a transaction context manager for banking case 3; use sample reference ACC-1095 and explain the result.

# %%
#Q75. Create a transaction context manager for banking case 1; use sample reference ACC-1075 and explain the result.
source={"Account_number":"ACC-1094","Balance":1000}
Beneficiary={"Account_number":"ACC-1095","Balance":0}
amount=int(input())
class Transaction():
    def __init__(self,source_acc,beneficiary_acc,source_balance,beneficiary_balance):
        self.source = {"Account_number": source_acc, "Balance": source_balance}
        self.beneficiary = {"Account_number": beneficiary_acc, "Balance": beneficiary_balance}
    def Validation(self,amount):
        if amount <= 0:raise ValueError("Amount must be > 0")
        if amount > self.source["Balance"]:raise ValueError("Insufficient Balance")
    def Recovery(self,amount):     
      try:
            self.Validation(amount)
            # perform transfer
            self.source["Balance"] -= amount
            self.beneficiary["Balance"] += amount
            print("Transaction Successful")
            print("Sender Balance:", self.source["Balance"])
            print("Beneficiary Balance:", self.beneficiary["Balance"])
            print("Transaction Committed")
            print("Transaction Closed")
      except ValueError as e:
            print("Transaction Failed:", e)
            print("Transaction Rolled Back")
            print("Sender Balance:", self.source["Balance"])
            print("Beneficiary Balance:", self.beneficiary["Balance"])
t = Transaction("ACC-1071", "ACC-1075", source["Balance"], Beneficiary["Balance"])
t.Recovery(amount)
# Out:
# Transaction Successful
# Sender Balance: 800
# Beneficiary Balance: 200
# Transaction Committed
# Transaction Closed

# %% [markdown]
# Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference ACC-1096 and explain the result.

# %%
dlq=[]
import time
Account_number="ACC-1096"
payment=[{"ID":101,"Balance":500},{"ID":102,"Balance":-200},{"ID":103,"Balance":0}]
for i in payment:
    try:
        if i["Balance"]<=2:
            raise ConnectionError("Invalid Payment")
        print("Payment Processed for ID :",i["ID"])
    except ConnectionError as c:
        print("Payment Failed for ID:",i["ID"])
        dlq.append({"Account number":Account_number,"ID":i["ID"],"Balance":i["Balance"], "Payment Failed":c})
        time.sleep(2)
print("Dead Letter queue:",dlq)
# Out:
# Payment Processed for ID : 101
# Payment Failed for ID: 102
# Payment Failed for ID: 103
# Dead Letter queue: [{'Account number': 'ACC-1096', 'ID': 102, 'Balance': -200, 'Payment Failed': ConnectionError('Invalid Payment')}, {'Account number': 'ACC-1096', 'ID': 103, 'Balance': 0, 'Payment Failed': ConnectionError('Invalid Payment')}]

# %% [markdown]
# Q97. Make batch settlement failure-isolated for banking case 3; use sample reference ACC-1097 and explain the result.

# %%
Account={
    "Account_no":["ACC-1091","ACC-1092","ACC-1093","ACC-1094","ACC-1095","ACC-1096","ACC-1097"],
    "Balance":[200,-300,500,100,1000,-900,0]
}
for i,j in enumerate(Account["Balance"]):
  try:
    if j<=0:
            raise ValueError("Incorrect Value")
    print(Account["Account_no"][i],"\n","Amount","-",j,"\n","Settlement Successful","\n")
  except ValueError as e:
    print(Account["Account_no"][i],"\n","Amount:",j, "\n","Settlement Failed:", e,"\n")
    continue
# Out:
# ACC-1091
#  Amount - 200
#  Settlement Successful
#
# ACC-1092
#  Amount: -300
#  Settlement Failed: Incorrect Value
#
# ACC-1093
#  Amount - 500
#  Settlement Successful
#
# ACC-1094
#  Amount - 100
#  Settlement Successful
#
# ACC-1095
#  Amount - 1000
#  Settlement Successful
#
# ACC-1096
#  Amount: -900
#  Settlement Failed: Incorrect Value
#
# ACC-1097
#  Amount: 0
#  Settlement Failed: Incorrect Value

# %% [markdown]
# Q98. Report exact paths in nested statements for banking case 3; use sample reference ACC-1098 and explain the result.

# %%
Customers={
    "Account_number":{"Account1":{"ACC-1098":{"Transactions":[200,-300,-400,0]}}}
}
for i, j in Customers["Account_number"].items():
    for k, v in j.items():
        for l,m  in enumerate(v["Transactions"]):
            try:
                if m <= 0:raise ValueError("Invalid transaction")
            except ValueError as e:
                print(
                    "Path: Account_number ->",
                    m, "->",
                    k, "-> Transactions ->",
                    i,
                    ":", e
                )
# Out:
# Path: Account_number -> -300 -> ACC-1098 -> Transactions -> Account1 : Invalid transaction
# Path: Account_number -> -400 -> ACC-1098 -> Transactions -> Account1 : Invalid transaction
# Path: Account_number -> 0 -> ACC-1098 -> Transactions -> Account1 : Invalid transaction

# %% [markdown]
# Q99. Design idempotent recovery after timeout for banking case 3; use sample reference ACC-1099 and explain the result.

# %%
Account_number="ACC-1099"
processed_time={"TXN-1010"}
txn=input()
try:
    if txn in processed_time:
        print(f"{txn} is already processed for {Account_number}-duplicates not allowed")
    else:
        raise TimeoutError("Payment Time Out")
except TimeoutError as t:
    print("Retrying payment",t) 
#     processed_time.add(txn)
# Out:
# TXN-1010 is already processed for ACC-1099-duplicates not allowed

# %% [markdown]
# Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference ACC-1100 and explain the result.

# %%
Account_number="ACC-1100"
Bank_records=[200,500,700,800,900,200]
payment_records=[200,500,900,800,700,1200]
for i,j in enumerate(Bank_records):
  try: 
    if j == payment_records[i]:
        print(f"{j} Matched")
    else:
        raise ValueError(f"{j} MissMatch")  
  except ValueError as e:
     print("Error:",e)
# Out:
# 200 Matched
# 500 Matched
# Error: 700 MissMatch
# 800 Matched
# Error: 900 MissMatch
# Error: 200 MissMatch
